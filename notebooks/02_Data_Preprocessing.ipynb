# %%
import os
import sys

# Get the absolute path of the project root
project_root = os.path.abspath("..")

# Add it to Python path
if project_root not in sys.path:
    sys.path.append(project_root)

print(project_root)
# Out:
# c:\Users\lokes\OneDrive\Documents\Desktop\emotion-detection\Emotion-detection-system

# %%
import sys

for p in sys.path:
    print(p)
# Out:
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\python312.zip
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\DLLs
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0
#
# C:\Users\lokes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages
# C:\Users\lokes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\win32
# C:\Users\lokes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\win32\lib
# C:\Users\lokes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\Pythonwin
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\site-packages
# c:\Users\lokes\OneDrive\Documents\Desktop\emotion-detection\Emotion-detection-system

# %%
pip install contractions
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting contractions
#   Using cached contractions-0.1.73-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting textsearch>=0.0.21 (from contractions)
#   Using cached textsearch-0.0.24-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting anyascii (from textsearch>=0.0.21->contractions)
#   Using cached anyascii-0.3.3-py3-none-any.whl.metadata (1.6 kB)
# Collecting pyahocorasick (from textsearch>=0.0.21->contractions)
#   Using cached pyahocorasick-2.3.1-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Using cached contractions-0.1.73-py2.py3-none-any.whl (8.7 kB)
# Using cached textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# Using cached anyascii-0.3.3-py3-none-any.whl (345 kB)
# Using cached pyahocorasick-2.3.1-cp312-cp312-win_amd64.whl (35 kB)
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.3 contractions-0.1.73 pyahocorasick-2.3.1 textsearch-0.0.24
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: C:\Users\lokes\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd

from src.preprocessing.pipeline import preprocess_dataframe

df = pd.read_csv("../data/raw/emotion_dataset.csv")

df = preprocess_dataframe(df)

df.to_csv(
    "../data/processed/cleaned_emotion_dataset.csv",
    index=False
)

df.head()
# Out:
#                                                 Text          One_Hot_Label  \
# 0  during the period of falling in love each time...  [1, 0, 0, 0, 0, 0, 0]
# 1          when i was involved in a traffic accident  [0, 1, 0, 0, 0, 0, 0]
# 2  when i was driving home after several days of ...  [0, 0, 1, 0, 0, 0, 0]
# 3    when i lost the person who meant the most to me  [0, 0, 0, 1, 0, 0, 0]
# 4  the time i knocked a deer down the sight of th...  [0, 0, 0, 0, 1, 0, 0]
#
#   Emotion_Label  Character_Count  Word_Count
# 0           joy              111          23
# 1          fear               42           8
# 2         anger              176          34
# 3       sadness               48          11
# 4       disgust              217          42
